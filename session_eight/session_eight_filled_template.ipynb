# %% [markdown]
# <a href="https://colab.research.google.com/github/warwickdatascience/beginners-python/blob/master/session_eight/session_eight_filled_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>Spotted a mistake? Report it <a href="https://github.com/warwickdatascience/beginners-python/issues/new">here</a></center>

# %% [markdown]
# # Beginner's Python—Session Eight Template

# %% [markdown]
# ## Reading From a Text File

# %% [markdown]
# ### Introduction

# %% [markdown]
# Read the contents of `the_joke.txt` and print it with correct formatting

# %%
with open('the_joke.txt') as file:
    contents = file.read()
print(contents)

# %% [markdown]
# Read `the_joke.txt` into a list, one element for each line of the text

# %%
with open('the_joke.txt') as file:
    contents = file.read()
    lines = contents.split('\n')
lines

# %% [markdown]
# ### Standard Puzzles

# %% [markdown]
# Print out every tenth line of the text file to obtain the passcode

# %%
with open('passcode.txt') as f:
    contents = f.read()
    lines = contents.split('\n')
    for i, l in enumerate(lines)
        if i % 10 == 0:
            print(l)

# %% [markdown]
# ## Reading Text Files Sequentially

# %% [markdown]
# ### Introduction

# %% [markdown]
# Read `the_joke.txt` one line at a time, printing each out

# %%
with open('the_joke.txt') as f:
    line = f.readline().replace('\n', '')
    while line:
        print(line)
        line = f.readline().replace('\n', '')

# %% [markdown]
# ### Standard Puzzles

# %% [markdown]
# Repeat the passcode exercise using sequential reading

# %%
with open('passcode.txt') as f:
    line = f.readline().replace('\n', '')
    cnt = 0
    while line:
        if cnt % 10 == 0:
            print(line)
        line = f.readline().replace('\n', '')
        cnt += 1

# %% [markdown]
# Read only the title and first line from `the_joke.txt`

# %%
with open('the_joke.txt') as f:
    for i in range(3):
        line = f.readline().replace('\n', '')
        print(line)

# %% [markdown]
# ## Writing to Text Files

# %% [markdown]
# ### Introduction

# %% [markdown]
# Write to a text file using write mode

# %%
with open('countdown.txt', 'w') as f:
    for i in range(10, 0):
        f.write(str(i) + '\n')

# %% [markdown]
# Write to a text file using append mode

# %%
with open('countdown.txt', 'a') as f:
    for i in range(6, 11):
        f.write(str(i) + '\n')

# %% [markdown]
# ### Standard Puzzles

# %% [markdown]
# Ask the user for their name and write this to a text file

# %%
name = input("What is your name? ")
with open('user_details', 'w') as f:
    f.write('Name: ' + name)

# %% [markdown]
# Ask the user for their favourite food and append this on a new line to the same text file

# %%
food = input("What is your favourite food? ")
with open('user_details', 'a') as f:
    f.write('\nFavourite Food: ' + food)

# %% [markdown]
# ### Bonus Puzzles

# %% [markdown]
# What happens when you append to a file that doesn't exist?

# %%
with open('non_existant_file', 'a') as f:
    f.write('text')

# %% [markdown]
# The file is created

# %% [markdown]
# ## Raising Errors

# %% [markdown]
# ### Introduction

# %% [markdown]
# Create a function that accepts a positive integer and raise a `ValueError` if the argument is not positive

# %%
def count_to(n):
    if n < 1:
        raise ValueError('n must be positive')
    for i in range(n):
        print(i + 1)

# %%
count_to(4)
count_to(-1)
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ed95bc215ae9> in <module>
#       1 count_to(4)
# ----> 2 count_to(-1)
#
# <ipython-input-1-6fd50b2010d5> in count_to(n)
#       1 def count_to(n):
#       2     if n < 1:
# ----> 3         raise ValueError('n must be positive')
#       4     for i in range(n):
#       5         print(i + 1)
#
# ValueError: n must be positive

# %% [markdown]
# Test the `isinstance()` function

# %%
x = 4
if isinstance(x, int):
    print("x is an integer")
if isinstance(x, float):
    print("x is a float")
if isinstance(x, str):
    print("x is a string")
# Out:
# x is an integer

# %% [markdown]
# Test the `isnumeric()` and `isalpha()` methods

# %%
y = "A"
z = "1"
if y.isnumeric():
    print("y is numeric")
if z.isnumeric():
    print("z is numeric")
if y.isalpha():
    print("y is alphabetic")
if z.isalpha():
    print("z is alphabetic")
# Out:
# z is numeric
# y is alphabetic

# %% [markdown]
# Test the `in` keyword for strings

# %%
u = 'ABC'
v = 'CDE'
if 'BC' in u:
    print("Found 'BC' in u")
if 'BC' in v:
    print("Found 'BC' in u")
# Out:
# Found 'BC' in u

# %% [markdown]
# ### Standard Puzzles

# %% [markdown]
# Create the `print_sentence` function as specified in the presentation

# %%
def print_sentence(text):
    if not isinstance(text, str):
        raise TypeError("text must be a string")
    if not ' ' in text:
        raise ValueError("text must contain a space")
    print(text)

# %% [markdown]
# Create the `forgiving_double` function as specified in the presentation

# %%
def forgiving_double(value):
    if isinstance(value, str):
        if value.isnumeric():
            value = int(value)
        else:
            raise ValueError("value must be numeric")
    return value * 2

# %% [markdown]
# ## Built-in Modules

# %% [markdown]
# ### Introduction

# %% [markdown]
# Import the `time` module to use the `time` function

# %%
import time

# Number of seconds since 01/01/1970
print(round(time.time()))
# Out:
# 1594594177

# %% [markdown]
# Import the `randint` function from the `random` module and use it

# %%
from random import randint

# Random number between 1 and 10
print(randint(1, 10))
# Out:
# 8

# %% [markdown]
# Use `os.path.exists()` to test if a file exists and raise an error if not

# %%
import os

if os.path.exists("text_file.txt"):
    import_file()
else:
    raise OSError("could not find file")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-e97d5f489ad7> in <module>
#       4     import_file()
#       5 else:
# ----> 6     raise OSError("could not find file")
#
# OSError: could not find file

# %% [markdown]
# Import the `datetime` module as `dt` and use it to print the current date

# %%
import datetime as dt

print(dt.date.today())
# Out:
# 2020-07-12

# %% [markdown]
# Import the `normalvariate` function as `rnorm` and use it to print a random normal variable

# %%
from random import normalvariate as rnorm

rnorm(0, 1)
# Out:
# 1.0481737534513071

# %% [markdown]
# ### Standard Puzzles

# %% [markdown]
# Create a guessing game

# %%
import random as rand

answer = rand.randint(1, 20)
tries = 0
correct = False
while tries < 3:
    guess = int(input("Guess a number: "))
    if guess == answer:
        print("Correct!")
        correct = True
        break
    elif guess < answer:
        print("Too low")
    else:
        print("Too high")
    tries += 1

if correct:
    print("You win")
else:
    print("You lose")
# Out:
# Guess a number: 4
# Too low
# Guess a number: 10
# Too low
# Guess a number: 15
# Too high
# You lose

# %% [markdown]
# Use the `combinations` function from `itertools` to list all possible pairs of the names Ann, Bob, and Cat

# %%
from itertools import combinations

names = ['Ann', 'Bob', 'Cat']
for first, second in combinations(names, 2):
    print(first, second)
# Out:
# Ann Bob
# Ann Cat
# Bob Cat
